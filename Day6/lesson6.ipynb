# %%
import pandas as pd

# %%
kg = [37, 48, 42, 39, 41, 38, 40, 40, 100]

kg_list = pd.Series(kg, index = ["Hoa", "Nam", "Hải", "Linh", "Nhân", "Phương", "Thu", "Vũ", "Bảo"])

kg_list
# Out:
# Hoa       37
# Nam       48
# Hải       42
# Linh      39
# Nhân      41
# Phương    38
# Thu       40
# Vũ        40
# Bảo       43
# dtype: int64

# %%
print("mean: ", kg_list.mean() )
print("median: ", kg_list.median() )
print("mode: ", kg_list.mode()[0])

# print(kg_list[kg_list == kg_list.mode()[0]])

# kg_list.nlargest(1)
# Out:
# mean:  40.888888888888886
# median:  40.0
# mode:  40

# %%
data = {
    "dong_vat": ["Sao la", "Khỉ đuôi rắn", "Voi châu Á"],
    "tuoi_tho": [25, 25, 70],
    "loai": ["có vú", "linh trưởng", "có vú"]
}

df = pd.DataFrame(data)
df.describe()
# Out:
#         tuoi_tho
# count   3.000000
# mean   40.000000
# std    25.980762
# min    25.000000
# 25%    25.000000
# 50%    25.000000
# 75%    47.500000
# max    70.000000

# %%
data = {
    "Name": ['john', 'jane', 'doe'],
    'Age': [30,25,35],
    'City': ['NYC', 'LA', "Chicago"]
}
df = pd.DataFrame(data)
df.to_csv('output.csv', index=False)

# %%
df_read = pd.read_csv('output.csv')
print(df_read[:2])
print(df_read[["Name", "Age"]])
# Out:
#    Name  Age City
# 0  john   30  NYC
# 1  jane   25   LA
#    Name  Age
# 0  john   30
# 1  jane   25
# 2   doe   35
