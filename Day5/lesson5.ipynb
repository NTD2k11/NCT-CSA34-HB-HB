# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
fruit = ["banana", "apple", "orange", "cherry", "pear"]

fruit_table = pd.Series(fruit, index = ["A", "B", "C", "D", "E"])
print(fruit_table)
# Out:
# A    banana
# B     apple
# C    orange
# D    cherry
# E      pear
# dtype: str
